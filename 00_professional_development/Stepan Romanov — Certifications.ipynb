# %% [markdown]
# # 📜 Stepan Romanov: Professional Development & Certifications
#
# This notebook documents my continuous learning journey across **data science, machine learning, marketing analytics, and software engineering**. Certifications are grouped by domain and presented with estimated hours, core content, and their practical value in solving real business problems.
#
# ---
# > **Purpose:** Portfolio reference for recruiters, collaborators, and hiring managers reviewing my [GitHub marketing research & analytics projects](https://github.com/stepanaromanov/python_for_marketing_research_and_analytics).
# >
# > **Total certifications:** 18 | **Span:** 2019 – 2026 | **Platforms:** DataCamp · Coursera · HubSpot · Google · University of Helsinki · Yandex Practicum | **Last updated:** 2026/07/19

# %% [markdown]
# ## Portfolio
#
# **[stepanaromanov.github.io](https://stepanaromanov.github.io)** — Marketing Research & Analytics Projects
#
# | # | Project | Description |
# |---|---------|----------|
# | 01 | [Markov Chain Multi-Touch Attribution](https://stepanaromanov.github.io/01_markov_chain_mta.html) | E-commerce channel credit allocation with ground-truth validation and MLOps deployment |
# | 02 | [Shapley Value Attribution for Paid Media](https://stepanaromanov.github.io/02_shapley_attribution.html) | Fair marginal contribution analysis for overlapping B2B channels with ground-truth validation and MLOps |
# | 03 | [Meridian Media Mix Modeling](https://stepanaromanov.github.io/03_meridian_mmm.html) | Digital + TV spend with geo-level Bayesian inference and automated retraining |
# | 04 | [Shapley-Based Budget Optimizer](https://stepanaromanov.github.io/04_budget_optimizer.html) | MLOps-optimised budget reallocation with PuLP linear programming and canary rollout |
# | 05 | [Full Multi-Touch Attribution Engine](https://stepanaromanov.github.io/05_multi_touch_attribution_engine.html) | Comprehensive comparison of 8 attribution models with ground-truth validation and production MLOps |
# | 06 | [PyMC MMM with External Regressors](https://stepanaromanov.github.io/06_pymc_mmm_external_regressors.html) | Bayesian sales modeling with competitive and macroeconomic controls, parameter-recovery validation, and automated retraining |
# | 07 | [Customer Segmentation & Causal Inference](https://stepanaromanov.github.io/07_customer_segmentation_causal.html) | Causal uplift modeling that separates true discount response from spending level, with validated segmentation and parameter recovery |
# | 08 | [A/B Testing Orchestration](https://stepanaromanov.github.io/08_ab_testing_orchestration.html) | *(Improvements are currently in progress)* |
# | 09 | [Survival & Retention MMM](https://stepanaromanov.github.io/09_survival_retention_mmm.html) | *(Improvements are currently in progress)* |

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Certification Registry
#
# All certifications are structured with the following fields:
# - **Group** – domain / skill cluster
# - **Certificate** – official name with verification link
# - **Issuer** – platform or institution
# - **Year** – completion year
# - **Est. Hours** – estimated study hours based on curriculum scope
# - **Core Content** – key topics covered
# - **Business Value** – how the skills translate to real-world problem-solving

# %%
certifications = [

    # ── GROUP 1: Machine Learning & MLOps ──────────────────────────────────────
    {
        "Group": "Machine Learning & MLOps",
        "Certificate": "MLOps Fundamentals",
        "Issuer": "DataCamp",
        "Year": 2026,
        "Est. Hours": 14,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/fa2b32fd36473499fa6511c50c54060da6722bb4",
        "Core Content": "Model deployment pipelines, CI/CD for ML, experiment tracking (MLflow), model monitoring, feature stores",
        "Business Value": "Enables reliable, repeatable deployment of ML models to production; reduces model drift and downtime in customer-facing AI products"
    },
    {
        "Group": "Machine Learning & MLOps",
        "Certificate": "Machine Learning in Production",
        "Issuer": "DataCamp",
        "Year": 2026,
        "Est. Hours": 19,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/39a2724d0abc00a50409f86a01c07a2bc8f45843",
        "Core Content": "A/B testing for ML, monitoring data drift, concept drift, model degradation, retraining strategies",
        "Business Value": "Bridges the gap between data science prototypes and scalable business solutions; ensures models deliver consistent ROI post-deployment"
    },

    # ── GROUP 2: Statistics & Probability ──────────────────────────────────────
    {
        "Group": "Statistics & Probability",
        "Certificate": "Time Series with Python",
        "Issuer": "DataCamp",
        "Year": 2026,
        "Est. Hours": 20,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/43f39275215d2c3f98e92f6b5c0708a6b19b2ed8",
        "Core Content": "pandas time series manipulation (resampling, rolling & expanding windows); correlation & autocorrelation, stationarity; AR/MA/ARMA and ARIMA/SARIMA modelling with estimation, forecasting & selection (AIC/BIC); seasonality/trend decomposition and diagnostics; feature engineering and ML for time series with time-aware validation",
        "Business Value": "End-to-end forecasting across time series–driven domains, notably sales/demand planning and finance (prices, volatility, risk). Turns historical signals into reliable forward estimates via seasonality/trend decomposition, ARIMA/SARIMA and ML forecasts, and proper time-aware validation — driving planning, budgeting, and anomaly detection under uncertainty"
    },
    {
        "Group": "Statistics & Probability",
        "Certificate": "Statistical Simulation in Python",
        "Issuer": "DataCamp",
        "Year": 2026,
        "Est. Hours": 4,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/course/f05d5f19e722a19cda5fb9628996cece59a7f236",
        "Core Content": "Monte Carlo simulations, bootstrapping, resampling methods, probability distributions, random number generation, scenario modelling",
        "Business Value": "Quantifies uncertainty in forecasts and pricing models; supports risk assessment and budget planning under variable market conditions"
    },
    {
        "Group": "Statistics & Probability",
        "Certificate": "Applied Statistics in Python",
        "Issuer": "Datacamp",
        "Year": 2024,
        "Est. Hours": 16,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/746469fdfe1f1158456b0cc0574b199ede5e60b2",
        "Core Content": "Experimental design, statistical inference, Bayesian data analysis",
        "Business Value": "Helps run smarter experiments, make statistically sound decisions, and use Bayesian models to better predict customer behavior, optimize campaigns, and improve ROI under uncertainty."
    },
    {
        "Group": "Statistics & Probability",
        "Certificate": "Calculus for Machine Learning and Data Science",
        "Issuer": "Coursera",
        "Year": 2024,
        "Est. Hours": 26,
        "Verify URL": "https://www.coursera.org/account/accomplishments/verify/VVA8DEK8H4XX",
        "Core Content": "Derivatives & optimisation (gradient descent mechanics), partial derivatives & multivariate calculus, chain rule & backpropagation, Taylor series approximations, Jacobians & Hessians, Lagrange multipliers for constrained optimisation",
        "Business Value": "Provides the mathematical engine behind ML model training — understanding how gradient descent actually minimises loss functions enables better hyperparameter tuning, diagnosing convergence issues, and making informed model architecture decisions"
    },
    {
        "Group": "Statistics & Probability",
        "Certificate": "Linear Algebra for Machine Learning",
        "Issuer": "Coursera",
        "Year": 2023,
        "Est. Hours": 34,
        "Verify URL": "https://coursera.org/verify/3U6ANS7DB9U5",
        "Core Content": "Vectors, matrices, eigenvalues/eigenvectors, linear transformations, applications in ML algorithms",
        "Business Value": "Provides mathematical foundation for understanding dimensionality reduction, recommendation engines, and NLP — enabling better model selection and debugging"
    },
    {
        "Group": "Statistics & Probability",
        "Certificate": "Probability Theory for Beginners",
        "Issuer": "Coursera / MIPT",
        "Year": 2022,
        "Est. Hours": 23,
        "Verify URL": "https://www.coursera.org/account/accomplishments/verify/5BAE49US82V6",
        "Core Content": "Conditional probability, Bayes' theorem, random variables, expected value, distributions, hypothesis testing fundamentals",
        "Business Value": "Underpins sound A/B testing interpretation, cohort analysis, and any data-driven decision-making involving uncertainty"
    },

    # ── GROUP 3: Data Engineering ───────────────────────────────────────────────
    {
        "Group": "Data Engineering",
        "Certificate": "Big Data with PySpark",
        "Issuer": "DataCamp",
        "Year": 2026,
        "Est. Hours": 25,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/10593f9f85e940bea9d871f6afffa78ce5b3eb1a",
        "Core Content": "Distributed computation with Apache Spark via PySpark, RDDs & DataFrames, Spark SQL, data cleaning at scale, feature engineering pipelines, ML with Spark MLlib (regression, trees, pipelines), collaborative-filtering recommendation engines",
        "Business Value": "Unlocks analytics and ML on datasets that exceed single-machine memory — distributed Spark processing removes the need to sample, preserving statistical power and enabling segmentation, feature engineering, and modelling across full populations at production scale"
    },
    {
        "Group": "Data Engineering",
        "Certificate": "AWS Cloud Practitioner (CLF-C02)",
        "Issuer": "DataCamp",
        "Year": 2026,
        "Est. Hours": 10,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/6521462fc4029630ba39fd1b8d547f6d1dccf02b",
        "Core Content": "Cloud computing fundamentals, AWS core services (EC2, S3, RDS, Lambda), networking & security, IAM & shared responsibility model, cost optimisation & pricing models, AWS Well-Architected Framework",
        "Business Value": "Enables informed cloud infrastructure decisions — selecting, securing, and cost-optimising AWS services for scalable data pipelines and ML deployments without over-reliance on engineering teams"
    },
    {
        "Group": "Data Engineering",
        "Certificate": "Data Engineer in Python",
        "Issuer": "DataCamp",
        "Year": 2024,
        "Est. Hours": 36,
        "Verify URL": "https://www.datacamp.com/completed/statement-of-accomplishment/track/a9a968011da228fee4abf1359b4cfb98664d3b31",
        "Core Content": "ETL/ELT pipelines, Airflow, data warehousing, data quality",
        "Business Value": "Builds robust data pipelines that ensure clean, timely data reaches analytics and ML systems — reducing errors in reporting and model inputs"
    },
    {
        "Group": "Data Engineering",
        "Certificate": "Data Analyst Semi-Annual Course (ID 20212DA00352)",
        "Issuer": "Yandex Practicum",
        "Year": 2021,
        "Est. Hours": 250,
        "Verify URL": "",
        "Core Content": "SQL, Python for data analysis, statistical testing, cohort analysis, data visualisation, product analytics, dashboards",
        "Business Value": "Foundational training enabling end-to-end analytical workflows — from raw data extraction to actionable business insights and stakeholder reporting"
    },

    # ── GROUP 4: Marketing Analytics ───────────────────────────────────────────
    {
        "Group": "Marketing Analytics",
        "Certificate": "Marketing Analytics with Python",
        "Issuer": "DataCamp",
        "Year": 2023,
        "Est. Hours": 28,
        "Verify URL": "https://www.datacamp.com/statement-of-accomplishment/track/c9c8e74ac2d4a566a00840c68e3a4a43fe411268",
        "Core Content": "Customer segmentation, CLV modelling, churn prediction, social media networks analysis, market basket analysis, campaign performance analysis, funnel analytics",
        "Business Value": "Translates marketing spend data into measurable ROI; identifies high-value customer segments and optimises acquisition and retention budgets"
    },
    {
        "Group": "Marketing Analytics",
        "Certificate": "Marketing Analytics",
        "Issuer": "Coursera",
        "Year": 2019,
        "Est. Hours": 16,
        "Verify URL": "https://www.coursera.org/account/accomplishments/verify/8LWUUKW62NKF",
        "Core Content": "Market research methods, regression for marketing, conjoint analysis, brand analytics, customer decision modelling",
        "Business Value": "Applies quantitative frameworks to marketing strategy — improving pricing decisions, product positioning, and competitive analysis"
    },
    {
        "Group": "Marketing Analytics",
        "Certificate": "Marketing Analytics with R",
        "Issuer": "DataCamp",
        "Year": 2019,
        "Est. Hours": 16,
        "Verify URL": "https://www.datacamp.com/statement-of-accomplishment/track/c5f05ddf98ef1c03e4f2782fc20831cf842797c4",
        "Core Content": "Customer choice modeling, regression, clustering, A/B test analysis, social media analytics",
        "Business Value": "Enables statistical marketing analysis in R — useful for cross-validating Python models and working with R-native marketing datasets and tools"
    },

    # ── GROUP 5: Revenue Operations & CRM ─────────────────────────────────────
    {
        "Group": "Revenue Operations & CRM",
        "Certificate": "Revenue Operations",
        "Issuer": "HubSpot Academy",
        "Year": 2023,
        "Est. Hours": 8,
        "Verify URL": "https://app.hubspot.com/academy/achievements/31gkr6xh/en/1/stefan-romanoff/revenue-operations",
        "Core Content": "RevOps strategy, sales & marketing alignment, CRM data management, pipeline reporting, forecasting, tech stack integration",
        "Business Value": "Aligns sales, marketing and CS around shared revenue metrics; reduces data silos and improves pipeline visibility for leadership decisions"
    },

    # ── GROUP 6: Web Analytics ─────────────────────────────────────────────────
    {
        "Group": "Web & Product Analytics",
        "Certificate": "Google Analytics",
        "Issuer": "Google Skillshop",
        "Year": 2023,
        "Est. Hours": 10,
        "Verify URL": "https://skillshop.credential.net/1293261a-9cf6-4e8d-891a-6161026a2041",
        "Core Content": "GA4 setup and events, audience segmentation, conversion tracking, attribution models, custom reports, BigQuery export",
        "Business Value": "Delivers granular visibility into user behaviour and campaign performance; enables data-driven optimisation of digital marketing spend and UX"
    },

    # ── GROUP 7: Software Engineering ─────────────────────────────────────────
    {
        "Group": "Software Engineering",
        "Certificate": "Full Stack Open",
        "Issuer": "University of Helsinki",
        "Year": 2023,
        "Est. Hours": 200,
        "Verify URL": "https://studies.cs.helsinki.fi/stats/api/certificate/fullstackopen/en/e13da0d321a85a98f185e415b5fd18bd",
        "Core Content": "React, Node.js, REST APIs, GraphQL, MongoDB, TypeScript, testing, CI/CD, Docker, state management",
        "Business Value": "Enables building and deploying full-stack data products and internal tools — bridging the gap between analytics insights and user-facing applications"
    },
]

df = pd.DataFrame(certifications)
print(f"Total certifications loaded: {len(df)}")
print(f"Groups: {df['Group'].nunique()}")
print(f"Total estimated learning hours: {df['Est. Hours'].sum()}")
# Out:
# Total certifications loaded: 18
# Groups: 7
# Total estimated learning hours: 755

# %% [markdown]
# ## 2. Certifications Table (Grouped by Domain)

# %%
# ── Colour palette per group ───────────────────────────────────────────────────
group_colors = {
    "Machine Learning & MLOps":    "#0072B2",
    "Statistics & Probability":    "#009E73",
    "Data Engineering":            "#56B4E9",
    "Marketing Analytics":         "#D55E00",
    "Revenue Operations & CRM":    "#CC79A7",
    "Web & Product Analytics":     "#F0E442",
    "Software Engineering":        "#E69F00",
}

def make_link(row):
    """Wrap certificate name in an HTML anchor if a URL exists."""
    if row["Verify URL"]:
        return f'<a href="{row["Verify URL"]}" target="_blank">{row["Certificate"]}</a>'
    return row["Certificate"]

display_df = df.copy()
display_df["Certificate"] = display_df.apply(make_link, axis=1)
display_df = display_df.drop(columns=["Verify URL"])

# ── Build styled HTML table ────────────────────────────────────────────────────
rows_html = ""
prev_group = None

for _, row in display_df.iterrows():
    group = row["Group"]
    color = group_colors.get(group, "#f9f9f9")

    if group != prev_group:
        group_count = len(df[df["Group"] == group])
        rows_html += f"""
        <tr>
          <td rowspan="{group_count}"
              style="background:{color}; font-weight:700; font-size:13px;
                     vertical-align:middle; text-align:center;
                     border-right:2px solid #ccc; padding:10px 14px;
                     white-space:nowrap;">
            {group}
          </td>
        """
        prev_group = group
    else:
        rows_html += "<tr>"

    rows_html += f"""
          <td style="padding:8px 12px;">{row['Certificate']}</td>
          <td style="padding:8px 12px; white-space:nowrap;">{row['Issuer']}</td>
          <td style="padding:8px 12px; text-align:center;">{row['Year']}</td>
          <td style="padding:8px 12px; text-align:center; font-weight:600;">{row['Est. Hours']} h</td>
          <td style="padding:8px 12px; font-size:12.5px;">{row['Core Content']}</td>
          <td style="padding:8px 12px; font-size:12.5px;">{row['Business Value']}</td>
        </tr>
    """

table_html = f"""
<style>
  table.cert-table {{
    border-collapse: collapse;
    width: 100%;
    font-family: 'Segoe UI', Arial, sans-serif;
    font-size: 13px;
    box-shadow: 0 2px 8px rgba(0,0,0,0.08);
  }}
  table.cert-table th {{
    background: #2c3e50;
    color: #ffffff;
    padding: 11px 14px;
    text-align: left;
    font-size: 12.5px;
    letter-spacing: 0.4px;
  }}
  table.cert-table td {{
    border: 1px solid #e0e0e0;
    vertical-align: top;
    line-height: 1.5;
  }}
  table.cert-table tr:hover td {{
    background: #f0f4ff !important;
  }}
  table.cert-table a {{
    color: #1a73e8;
    text-decoration: none;
    font-weight: 600;
  }}
  table.cert-table a:hover {{ text-decoration: underline; }}
</style>
<table class="cert-table">
  <thead>
    <tr>
      <th>Domain Group</th>
      <th>Certificate</th>
      <th>Issuer</th>
      <th>Year</th>
      <th>Est. Hours</th>
      <th>Core Content</th>
      <th>Business Value</th>
    </tr>
  </thead>
  <tbody>
    {rows_html}
  </tbody>
</table>
"""

# %%
display(HTML(table_html))
# Out:
# <style>
#   table.cert-table {
#     border-collapse: collapse;
#     width: 100%;
#     font-family: 'Segoe UI', Arial, sans-serif;
#     font-size: 13px;
#     box-shadow: 0 2px 8px rgba(0,0,0,0.08);
#   }
#   table.cert-table th {
#     background: #2c3e50;
#     color: #ffffff;
#     padding: 11px 14px;
#     text-align: left;
#     font-size: 12.5px;
#     letter-spacing: 0.4px;
#   }
#   table.cert-table td {
#     border: 1px solid #e0e0e0;
#     vertical-align: top;
#     line-height: 1.5;
#   }
#   table.cert-table tr:hover td {
#     background: #f0f4ff !important;
#   }
#   table.cert-table a {
#     color: #1a73e8;
#     text-decoration: none;
#     font-weight: 600;
#   }
#   table.cert-table a:hover { text-decoration: underline; }
# </style>
# <table class="cert-table">
#   <thead>
#     <tr>
#       <th>Domain Group</th>
#       <th>Certificate</th>
#       <th>Issuer</th>
#       <th>Year</th>
#       <th>Est. Hours</th>
#       <th>Core Content</th>
# ...

# %% [markdown]
# ## 3. Summary Statistics

# %%
summary = (
    df.groupby("Group")
    .agg(
        Certifications=("Certificate", "count"),
        Total_Hours=("Est. Hours", "sum"),
        Avg_Hours=("Est. Hours", "mean"),
        Latest_Year=("Year", "max")
    )
    .reset_index()
    .sort_values("Total_Hours", ascending=False)
)

summary["Avg_Hours"] = summary["Avg_Hours"].round(1)

summary_style = summary.style \
    .set_caption("📊 Summary by Domain Group") \
    .background_gradient(subset=["Total_Hours"], cmap="Blues") \
    .background_gradient(subset=["Certifications"], cmap="Greens") \
    .format({"Avg_Hours": "{:.1f} h", "Total_Hours": "{} h"}) \
    .set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '15px'), ('font-weight', 'bold'), ('padding-bottom', '8px')]
    }])

display(summary_style)
print(f"\n── Grand Total ──")
print(f"  Certifications : {df['Certificate'].nunique()}")
print(f"  Learning Hours : {df['Est. Hours'].sum()} h")
print(f"  Year Range     : {df['Year'].min()} – {df['Year'].max()}")
# Out:
# <style type="text/css">
# #T_f99f0 caption {
#   font-size: 15px;
#   font-weight: bold;
#   padding-bottom: 8px;
# }
# #T_f99f0_row0_col1 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_f99f0_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f99f0_row1_col1, #T_f99f0_row5_col1, #T_f99f0_row6_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_f99f0_row1_col2 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_f99f0_row2_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f99f0_row2_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_f99f0_row3_col1 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_f99f0_row3_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_f99f0_row4_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_f99f0_row4_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_f99f0_row5_col2 {
#   background-color: #f6faff;
# ...

# %% [markdown]
# ## 4. Visualisations

# %%
palette = list(group_colors.values())
groups  = summary["Group"].tolist()
colors  = [group_colors.get(g, "#cccccc") for g in groups]
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle("Professional Development – Overview", fontsize=15, fontweight="bold", y=1.01)

# ── Chart 1: Hours per group (horizontal bar) ─────────────────────────────────
ax1 = axes[0]
bars = ax1.barh(summary["Group"], summary["Total_Hours"], color=colors, edgecolor="white", height=0.6)
for bar, val in zip(bars, summary["Total_Hours"]):
    ax1.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2,
             f"{val} h", va="center", fontsize=10)
ax1.set_title("Total Learning Hours by Domain", fontweight="medium", pad=12)
ax1.set_xlabel("Hours")
ax1.invert_yaxis()
ax1.spines[["top", "right"]].set_visible(False)
ax1.set_xlim(0, summary["Total_Hours"].max() * 1.2)

# ── Chart 2: Certifications count pie ────────────────────────────────────────
ax2 = axes[1]
wedges, texts, autotexts = ax2.pie(
    summary["Certifications"],
    labels=None,
    colors=colors,
    autopct=lambda p: f"{p:.0f}%" if p > 6 else "",
    startangle=140,
    pctdistance=0.78,
    center=(0, 0.35), 
    radius=0.75,                        
    wedgeprops=dict(edgecolor="white", linewidth=1.5)
)
for at in autotexts:
    at.set_fontsize(9)
ax2.legend(wedges, summary["Group"], loc="lower center",
           bbox_to_anchor=(0.5, -0.1), fontsize=8, ncol=1)

# ── Chart 3: Timeline – certs per year ───────────────────────────────────────
ax3 = axes[2]
year_counts = df.groupby("Year")["Certificate"].count().reset_index()
year_hours  = df.groupby("Year")["Est. Hours"].sum().reset_index()

ax3.bar(year_hours["Year"], year_hours["Est. Hours"],
        color="#0072B2", edgecolor="white", label="Hours", zorder=3)

ax3b = ax3.twinx()
ax3b.plot(year_counts["Year"], year_counts["Certificate"],
          color="#D55E00", marker="o", linewidth=3, label="# Certs", zorder=4)

ax3.set_title("Certifications & Hours by Year", fontweight="medium", pad=12)
ax3.set_xlabel("Year")
ax3.set_ylabel("Est. Hours", color="#0072B2")
ax3.tick_params(axis="y", labelcolor="#0072B2")
ax3b.set_ylabel("Number of Certifications", color="#D55E00")
ax3b.tick_params(axis="y", labelcolor="#D55E00")
ax3b.yaxis.set_major_locator(MaxNLocator(integer=True))
ax3b.grid(False)
ax3.set_xticks(year_counts["Year"])
ax3.set_axisbelow(True)
ax3.grid(axis="y", alpha=0.5, zorder=0)
ax3.spines[["top"]].set_visible(False)

lines1, labels1 = ax3.get_legend_handles_labels()
lines2, labels2 = ax3b.get_legend_handles_labels()
ax3.legend(lines1 + lines2, labels1 + labels2, loc="upper left", fontsize=9)

plt.tight_layout()

# shift pie chart up after tight layout
shift = 0.07
pos = ax2.get_position()
ax2.set_position([pos.x0, pos.y0 + shift, pos.width, pos.height])
ax2.set_title("Share of Certifications by Domain", fontweight="medium", pad=12, y=pos.height+0.15)

plt.show()
