# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
from scipy.stats import levene
from itertools import combinations
from statsmodels.stats.multitest import multipletests
plt.style.use('ggplot')

# %%
# import data and convert column names to lower case
customers = pd.read_excel('data/CustomersData.xlsx', sheet_name='Customers')
discount_coupon = pd.read_csv('data/Discount_Coupon.csv')
online_sales = pd.read_csv('data/Online_Sales.csv')
for dataset in customers, discount_coupon, online_sales:
    dataset.columns = dataset.columns.str.lower()
display(customers.head()), display(discount_coupon.head()), display(online_sales.head())
# Out:
#    customerid gender    location  tenure_months
# 0       17850      M     Chicago             12
# 1       13047      M  California             43
# 2       12583      M     Chicago             33
# 3       13748      F  California             30
# 4       15100      M  California             49
#   month product_category coupon_code  discount_pct
# 0   Jan          Apparel      SALE10            10
# 1   Feb          Apparel      SALE20            20
# 2   Mar          Apparel      SALE30            30
# 3   Jan         Nest-USA      ELEC10            10
# 4   Feb         Nest-USA      ELEC20            20
#    customerid  transaction_id transaction_date     product_sku  \
# 0       17850           16679         1/1/2019  GGOENEBJ079499
# 1       17850           16680         1/1/2019  GGOENEBJ079499
# 2       17850           16681         1/1/2019  GGOEGFKQ020399
# 3       17850           16682         1/1/2019  GGOEGAAB010516
# 4       17850           16682         1/1/2019  GGOEGBJL013999
#
#                                  product_description product_category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    quantity  avg_price  delivery_charges coupon_status
# 0         1     153.71               6.5          Used
# 1         1     153.71               6.5          Used
# 2         1       2.05               6.5          Used
# 3         5      17.53               6.5      Not Used
# 4         1      16.50               6.5          Used
# (None, None, None)

# %%
# Convert discount coupon month to datetime
# Create the month mapping dictionary
month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4,
    'May': 5, 'Jun': 6, 'Jul': 7, 'Aug': 8,
    'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}
# Map the month abbreviations to their numerical representations
discount_coupon['month'] = discount_coupon['month'].map(month_mapping)
# Create a 'date' column using a fixed year and the month numbers
discount_coupon['month'] = pd.to_datetime(discount_coupon['month'].astype(str) + '-2019', format='%m-%Y')
# Convert the 'date' column to a period object representing the month
discount_coupon['month'] = discount_coupon['month'].dt.to_period('M')
discount_coupon.head()
# Out:
#      month product_category coupon_code  discount_pct
# 0  2019-01          Apparel      SALE10            10
# 1  2019-02          Apparel      SALE20            20
# 2  2019-03          Apparel      SALE30            30
# 3  2019-01         Nest-USA      ELEC10            10
# 4  2019-02         Nest-USA      ELEC20            20

# %%
# Create month column in online sales dataset
online_sales['transaction_date'] = pd.to_datetime(online_sales['transaction_date'], format='%m/%d/%Y')
online_sales['month'] = online_sales['transaction_date'].dt.to_period('M')
# keep only used / not used coupon status
online_sales = online_sales[online_sales['coupon_status'].isin(['Used', 'Not Used'])]
online_sales.head()
# Out:
#    customerid  transaction_id transaction_date     product_sku  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
# 2       17850           16681       2019-01-01  GGOEGFKQ020399
# 3       17850           16682       2019-01-01  GGOEGAAB010516
# 4       17850           16682       2019-01-01  GGOEGBJL013999
#
#                                  product_description product_category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    quantity  avg_price  delivery_charges coupon_status    month
# 0         1     153.71               6.5          Used  2019-01
# 1         1     153.71               6.5          Used  2019-01
# 2         1       2.05               6.5          Used  2019-01
# 3         5      17.53               6.5      Not Used  2019-01
# 4         1      16.50               6.5          Used  2019-01

# %%
# bring it all together
data = pd.merge(online_sales, customers, how='left', on='customerid')
data = pd.merge(data, discount_coupon, how='left', on=['month', 'product_category'])
data['total_amount'] =  data['quantity'] * data['avg_price'] + data['delivery_charges']
data.head()
# Out:
#    customerid  transaction_id transaction_date     product_sku  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
# 2       17850           16681       2019-01-01  GGOEGFKQ020399
# 3       17850           16682       2019-01-01  GGOEGAAB010516
# 4       17850           16682       2019-01-01  GGOEGBJL013999
#
#                                  product_description product_category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    quantity  avg_price  delivery_charges coupon_status    month gender  \
# 0         1     153.71               6.5          Used  2019-01      M
# 1         1     153.71               6.5          Used  2019-01      M
# 2         1       2.05               6.5          Used  2019-01      M
# 3         5      17.53               6.5      Not Used  2019-01      M
# 4         1      16.50               6.5          Used  2019-01      M
#
#   location  tenure_months coupon_code  discount_pct  total_amount
# 0  Chicago             12      ELEC10          10.0        160.21
# 1  Chicago             12      ELEC10          10.0        160.21
# 2  Chicago             12       OFF10          10.0          8.55
# 3  Chicago             12      SALE10          10.0         94.15
# 4  Chicago             12       AIO10          10.0         23.00

# %% [markdown]
# <b>Exploratory Data Analysis</b>

# %%
data.info(), data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25998 entries, 0 to 25997
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customerid           25998 non-null  int64
#  1   transaction_id       25998 non-null  int64
#  2   transaction_date     25998 non-null  datetime64[ns]
#  3   product_sku          25998 non-null  object
#  4   product_description  25998 non-null  object
#  5   product_category     25998 non-null  object
#  6   quantity             25998 non-null  int64
#  7   avg_price            25998 non-null  float64
#  8   delivery_charges     25998 non-null  float64
#  9   coupon_status        25998 non-null  object
#  10  month                25998 non-null  period[M]
#  11  gender               25998 non-null  object
#  12  location             25998 non-null  object
#  13  tenure_months        25998 non-null  int64
#  14  coupon_code          25804 non-null  object
#  15  discount_pct         25804 non-null  float64
#  16  total_amount         25998 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(7), period[M](1)
# memory usage: 3.6+ MB
# (None,
#           customerid  transaction_id      quantity     avg_price  \
#  count  25998.000000    25998.000000  25998.000000  25998.000000
#  mean   15352.609162    32417.536926      4.549311     52.076603
#  std     1764.576286     8638.220121     21.161263     64.015764
#  min    12346.000000    16679.000000      1.000000      0.390000
#  25%    13922.000000    25382.000000      1.000000      5.700000
#  50%    15311.000000    32652.000000      1.000000     16.990000
#  75%    17017.000000    39127.000000      2.000000    100.910000
#  max    18283.000000    48495.000000    900.000000    355.740000
#
#         delivery_charges  tenure_months  discount_pct  total_amount
#  count      25998.000000   25998.000000  25804.000000  25998.000000
#  mean          10.427011      26.143319     20.000775     98.646412
#  std           18.964201      13.461940      8.136437    174.989844
#  min            0.000000       2.000000     10.000000      4.650000
#  25%            6.000000      15.000000     10.000000     19.490000
#  50%            6.000000      27.000000     20.000000     42.385000
#  75%            6.500000      37.000000     30.000000    129.270000
#  max          521.360000      50.000000     30.000000  10518.390000  )

# %%
# Make distribution plots for different columns
for column in ['transaction_date', 
               'product_category', 
               'avg_price', 
               'gender', 
               'location',
               'tenure_months', 
               'discount_pct']:
    sns.displot(data[column])
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.xticks(rotation=90)
    plt.show()

# %%
# Make box plots for different columns
for column in ['quantity',
               'delivery_charges',
               'avg_price',
               'tenure_months']:
    # Create the box plot
    sns.boxplot(data=data, x='coupon_status', y=column, palette='muted')
    plt.title(f'Box Plot of {column} by Month and Coupon')
    plt.xlabel('Month')
    plt.ylabel(column)
    # Rotate x-axis tick labels by 90 degrees
    plt.xticks(rotation=90)
    plt.show()

# %%
# Create the catplot for different columns; it shows the interdependence between 'coupon status' and and categorical values of particular column
for column in ['product_category',
               'location',
               'gender',
               'tenure_months',
               'discount_pct']:
    # Calculate the percentages
    df_percentage = data.groupby([column, 'coupon_status']).size().reset_index(name='count')
    df_total = data.groupby(column).size().reset_index(name='total')
    df_percentage = pd.merge(df_percentage, df_total, on=column)
    df_percentage['percentage'] = df_percentage['count'] / df_percentage['total'] * 100
    # Create the catplot 
    g = sns.catplot(data=df_percentage, kind='bar', x=column, y='percentage', hue='coupon_status', 
                    height=4, aspect=1.5, palette='muted')
    g.fig.set_size_inches((15, 5))
    # Rotate x-axis tick labels by 90 degrees
    g.set_xticklabels(rotation=90)
    # Function to add labels to the bars
    def add_labels(ax):
        for p in ax.patches:
            ax.annotate(f'{p.get_height():.2f}%', 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='center', 
                        xytext=(0, 9), 
                        textcoords='offset points', 
                        fontsize=6)
    # Add labels to each subplot
    for ax in g.axes.flat:
        add_labels(ax)
    # Set the titles and labels
    g.set_axis_labels(column, 'Percentage')
    g.set_titles('Percentage of Observations by Coupon Status')
    g.fig.suptitle(f'{column} by Coupon Status', y=1.05)
    plt.show()

# %% [markdown]
# <b>Design the A/B Test</b>

# %% [markdown]
# Define the Objective:
# Determine if the use of discount coupons increases the average order value and transaction volume.
#
# Primary Metrics:
# Average order value (AOV)
# Total sales volume
#
# Secondary Metrics:
# Conversion rate
# Customer retention rate
#
# Create Hypotheses:
# Null Hypothesis (H0): Discount coupons do not affect the average order value or total sales volume.
# Alternative Hypothesis (H1): Discount coupons increase the average order value and total sales volume.
# Segment the Audience:
#
# Split customers into two groups based on the 'coupon_status' column:
# Group A: Customers who did not use a discount coupon.
# Group B: Customers who used a discount coupon.
#
# Duration: Use historical data over a fixed period 1 year.
#
# Randomization: Ensure that the split between coupon users and non-users is random if possible, or consider using propensity score matching to create comparable groups.

# %% [markdown]
# <b>Calculate key metrics</b>

# %%
# Calculate average order value for each group
aov = data.groupby('coupon_status')['total_amount'].mean()
# Calculate total sales volume for each group
total_sales = data.groupby('coupon_status')['total_amount'].sum()
# Display the results
print('average sum: ', aov, '\n'), print('total sum: ', total_sales)
# Out:
# average sum:  coupon_status
# Not Used    100.853312
# Used         97.648721
# Name: total_amount, dtype: float64
#
# total sum:  coupon_status
# Not Used     816306.71
# Used        1748302.70
# Name: total_amount, dtype: float64
# (None, None)

# %%
# How many products could be inside one transaction?
transaction_products = data.groupby('transaction_id')\
                            .agg({'transaction_date': 'count'})\
                            .reset_index().sort_values(by='transaction_date', ascending=False)
counts, bins, _ = plt.hist(transaction_products['transaction_date'], bins=35, color='darkcyan')
plt.title('Products per transaction')
plt.xticks(np.arange(int(min(transaction_products['transaction_date'])), int(max(transaction_products['transaction_date'])) + 1, 1))
# Add labels to each bin
for i in range(len(bins) - 1):
    if counts[i] > 0:
        plt.text((bins[i] + bins[i+1]) / 2, counts[i], int(counts[i]), ha='center', va='bottom', fontsize=6)
plt.show()

# %%
# Does coupon give discount for all products?
transaction_discounts = data.groupby(['transaction_id', 'coupon_status'])\
                            .agg({'product_sku': 'count'})\
                            .reset_index()[['transaction_id']]\
                            .value_counts()
plt.hist(transaction_discounts, color='darkcyan', bins=2)
plt.title('Discount status for each product per transaction')
plt.xticks(np.arange(int(min(transaction_discounts)), int(max(transaction_discounts)) + 1, 1))
# Define custom tick positions and labels
tick_positions = [1, 2]  # Example positions where you want the ticks
# Corresponding labels for the ticks
tick_labels = ['Used / Not Used (1)',  'Used + Not Used (2)']  
# Set custom x-ticks
plt.xticks(tick_positions, tick_labels, rotation=10)
plt.show()

# %%
transaction_distinct_coupons = data[data['coupon_status']=='Used'].groupby(['transaction_id'])\
                                .agg({'coupon_code': 'nunique'})\
                                .reset_index()[['coupon_code']]
transaction_distinct_coupons = transaction_distinct_coupons[transaction_distinct_coupons != 0]
counts, bins, _ = plt.hist(transaction_distinct_coupons, bins=5, color='darkcyan')
plt.xticks(np.arange(int(transaction_distinct_coupons.min()), int(transaction_distinct_coupons.max()) + 1, 1))
for i in range(len(bins) - 1):
    if counts[i] > 0:
        plt.text((bins[i] + bins[i+1]) / 2, counts[i], int(counts[i]), ha='center', va='bottom', fontsize=8)
plt.title('Unique coupons per transaction')
plt.show()

# %% [markdown]
# Based on above-mentioned findings we conclude that in one transaction:
# 1. Could exist one or more distinct products
# 2. Customer could or could not use the coupon. It is also possible to use coupon for some of the products only
# 3. Customer could use a few distinct coupons
#
# So we will not group data by customers or transactions. Instead, we will use values for each particular product SKU observation.

# %% [markdown]
# <b>Statistical tests</b>

# %% [markdown]
# <i>T-test for Average Order Value</i>

# %%
# Separate the transaction amounts by group
no_coupon = data[data['coupon_status'] == 'Used']['total_amount']
with_coupon = data[data['coupon_status'] == 'Not Used']['total_amount']
# Perform t-test
alpha = 0.05
t_stat, p_value = ttest_ind(no_coupon, with_coupon)
# Interpret the results based on the p-value
print('t_stat: ', t_stat)
print('p_value_aov: ', p_value)
if p_value < alpha:
    print("Reject the null hypothesis - there is a significant difference in average order value between the groups.")
else:
    print("Fail to reject the null hypothesis - no significant difference in average order value between the groups.")
# Out:
# t_stat:  -1.3672682895544501
# p_value_aov:  0.17155304892553497
# Fail to reject the null hypothesis - no significant difference in average order value between the groups.

# %% [markdown]
# We are going to conduct multiple tests to understand how coupons affect sales in different categories: product_category, month,	gender,	location, discount_pct
#
# p-value (Bonferroni): This is the p-value adjusted using the Bonferroni correction method. A Bonferroni-adjusted p-value greater than 0.05 typically indicates that the difference between the groups is not statistically significant after adjusting for multiple comparisons.
#
# p-value (FDR): This is the p-value adjusted using the False Discovery Rate (FDR) correction method (specifically the Benjamini-Hochberg procedure). FDR correction is less conservative than Bonferroni correction and is often preferred when conducting multiple hypothesis tests.
#
# When using the ttest_ind function (independent two-sample t-test) in statistical analysis, it is not strictly necessary to have equal sample sizes for the two groups being compared. However, there are some important considerations to keep in mind regarding sample size equality.
#
# For example, Equal Variances Assumption. The standard ttest_ind assumes that the two samples have equal variances. If the sample sizes are unequal, this assumption becomes more critical because the test is more sensitive to violations of the equal variances assumption when sample sizes differ. To address this, you can use the equal_var=False option in ttest_ind, which applies Welch's t-test, which does not assume equal variances.

# %%
# Write a function to perform pairwise t-tests for each combination of groups in filtered dataset (coupon_status='Used')
def pairwise_ttest(df, value, category):
    results = []
    for group1, group2 in combinations(df[category].unique(), 2):
        data_group1 = df[df[category] == group1][value]
        data_group2 = df[df[category] == group2][value]
        # Perform Levene's test to assess the equality of variances for a variable calculated for two or more groups
        stat, levene_p_value = levene(data_group1, data_group2)
        if levene_p_value > 0.05:
            variances_equal = True
        else:
            variances_equal = False
        # Perform t-test
        t_stat, p_val = ttest_ind(data_group1, data_group2, equal_var=variances_equal)
        results.append({'group1': group1, 'group2': group2, 't_stat': t_stat, 'p_val': p_val})
    # Extract raw p-values
    raw_p_values = [result['p_val'] for result in results]
    # Apply Bonferroni correction
    adjusted_p_values_bonf = multipletests(raw_p_values, method='bonferroni')[1]
    # Apply FDR correction (Benjamini-Hochberg procedure)
    adjusted_p_values_fdr = multipletests(raw_p_values, method='fdr_bh')[1]
    print(f"\n\033[1mPairwise t-tests within category: {category} \033[0m\n")
    # Print results
    for idx, result in enumerate(results):
        print(f"Comparison {idx+1}: Group {result['group1']} vs Group {result['group2']}, "
              f"p-value (raw): {result['p_val']:.6f}, "
              f"p-value (Bonferroni): {adjusted_p_values_bonf[idx]:.6f}, "
              f"p-value (FDR): {adjusted_p_values_fdr[idx]:.6f}, "
              f"variances are equal: {variances_equal}")
        
# Write a function to perform t-tests for each particular category to understand an impact of coupon usage
def categorical_ttest(df, value, categories):
    grouped = df.groupby([categories, 'coupon_status'])[value].apply(list).reset_index()
    # Perform t-test for every category 
    results = []
    for cat in df[categories].unique():
        data_used = grouped[(grouped[categories] == cat) & (grouped['coupon_status'] == 'Used')][value].values[0]
        data_not_used = grouped[(grouped[categories] == cat) & (grouped['coupon_status'] == 'Not Used')][value].values[0]
         # Perform Levene's test to assess the equality of variances for a variable calculated for two or more groups
        stat, levene_p_value = levene(data_used, data_not_used)
        if levene_p_value > 0.05:
            variances_equal = True
        else:
            variances_equal = False
        t_stat, p_val = ttest_ind(data_used, data_not_used, equal_var=variances_equal)
        results.append({
            categories : cat,
            't_statistic': t_stat,
            'p_value': p_val
        })
    # Print results
    print(f"\n\033[1mImpact of coupon usage on sales within category: {categories} \033[0m\n")
    for result in results:
        print(f"{categories} {result[categories]}: " 
              f"t-statistic = {result['t_statistic']:.4f}, "
              f"p-value = {result['p_value']:.4f}, "
              f"variances are equal: {variances_equal}")

# %%
data['discount_pct'] = data['discount_pct'].astype(str)
for category in 'product_category', 'month', 'gender', 'location', 'discount_pct':
    categorical_ttest(data, 'total_amount', category)
    pairwise_ttest(data[data['coupon_status'] == 'Used'], 'total_amount', category)
    print(50 * '=')
# Out:
# Impact of coupon usage on sales within category: product_category
#
# product_category Nest-USA: t-statistic = -0.1789, p-value = 0.8580, variances are equal: True
# product_category Office: t-statistic = 1.2249, p-value = 0.2207, variances are equal: True
# product_category Apparel: t-statistic = -1.5565, p-value = 0.1196, variances are equal: True
# product_category Bags: t-statistic = -1.5432, p-value = 0.1231, variances are equal: True
# product_category Drinkware: t-statistic = -1.0000, p-value = 0.3175, variances are equal: True
# product_category Notebooks & Journals: t-statistic = -1.8789, p-value = 0.0611, variances are equal: True
# product_category Lifestyle: t-statistic = 0.1741, p-value = 0.8618, variances are equal: True
# product_category Waze: t-statistic = -1.3180, p-value = 0.1886, variances are equal: True
# product_category Fun: t-statistic = -0.9064, p-value = 0.3676, variances are equal: True
# product_category Nest-Canada: t-statistic = -1.1211, p-value = 0.2642, variances are equal: True
# product_category Headgear: t-statistic = 0.9795, p-value = 0.3280, variances are equal: True
# product_category Google: t-statistic = 0.9116, p-value = 0.3662, variances are equal: True
# product_category More Bags: t-statistic = 1.0002, p-value = 0.3298, variances are equal: True
# product_category Gift Cards: t-statistic = -0.1682, p-value = 0.8669, variances are equal: True
# product_category Housewares: t-statistic = -1.2909, p-value = 0.2024, variances are equal: True
# product_category Bottles: t-statistic = 1.6491, p-value = 0.1016, variances are equal: True
# product_category Android: t-statistic = 0.9255, p-value = 0.3669, variances are equal: True
# product_category Backpacks: t-statistic = -0.3047, p-value = 0.7622, variances are equal: True
# product_category Accessories: t-statistic = -0.3531, p-value = 0.7247, variances are equal: True
# product_category Nest: t-statistic = 0.1391, p-value = 0.8894, variances are equal: True
#
# Pairwise t-tests within category: product_category
#
# Comparison 1: Group Nest-USA vs Group Office, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 2: Group Nest-USA vs Group Bags, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 3: Group Nest-USA vs Group Drinkware, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 4: Group Nest-USA vs Group Apparel, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 5: Group Nest-USA vs Group Lifestyle, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 6: Group Nest-USA vs Group Waze, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 7: Group Nest-USA vs Group Fun, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 8: Group Nest-USA vs Group Nest-Canada, p-value (raw): 0.000025, p-value (Bonferroni): 0.004673, p-value (FDR): 0.000066, variances are equal: False
# Comparison 9: Group Nest-USA vs Group Headgear, p-value (raw): 0.380022, p-value (Bonferroni): 1.000000, p-value (FDR): 0.497959, variances are equal: False
# Comparison 10: Group Nest-USA vs Group Google, p-value (raw): 0.756407, p-value (Bonferroni): 1.000000, p-value (FDR): 0.821242, variances are equal: False
# Comparison 11: Group Nest-USA vs Group Notebooks & Journals, p-value (raw): 0.072493, p-value (Bonferroni): 1.000000, p-value (FDR): 0.129829, variances are equal: False
# Comparison 12: Group Nest-USA vs Group More Bags, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 13: Group Nest-USA vs Group Gift Cards, p-value (raw): 0.000031, p-value (Bonferroni): 0.005982, p-value (FDR): 0.000083, variances are equal: False
# Comparison 14: Group Nest-USA vs Group Housewares, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 15: Group Nest-USA vs Group Android, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 16: Group Nest-USA vs Group Bottles, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 17: Group Nest-USA vs Group Backpacks, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 18: Group Nest-USA vs Group Accessories, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 19: Group Nest-USA vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 20: Group Office vs Group Bags, p-value (raw): 0.000003, p-value (Bonferroni): 0.000636, p-value (FDR): 0.000010, variances are equal: False
# Comparison 21: Group Office vs Group Drinkware, p-value (raw): 0.076252, p-value (Bonferroni): 1.000000, p-value (FDR): 0.132916, variances are equal: False
# Comparison 22: Group Office vs Group Apparel, p-value (raw): 0.000000, p-value (Bonferroni): 0.000079, p-value (FDR): 0.000001, variances are equal: False
# Comparison 23: Group Office vs Group Lifestyle, p-value (raw): 0.000010, p-value (Bonferroni): 0.001852, p-value (FDR): 0.000026, variances are equal: False
# Comparison 24: Group Office vs Group Waze, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 25: Group Office vs Group Fun, p-value (raw): 0.600004, p-value (Bonferroni): 1.000000, p-value (FDR): 0.693950, variances are equal: False
# Comparison 26: Group Office vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 27: Group Office vs Group Headgear, p-value (raw): 0.183648, p-value (Bonferroni): 1.000000, p-value (FDR): 0.279144, variances are equal: False
# Comparison 28: Group Office vs Group Google, p-value (raw): 0.093570, p-value (Bonferroni): 1.000000, p-value (FDR): 0.157330, variances are equal: False
# Comparison 29: Group Office vs Group Notebooks & Journals, p-value (raw): 0.000150, p-value (Bonferroni): 0.028416, p-value (FDR): 0.000374, variances are equal: False
# Comparison 30: Group Office vs Group More Bags, p-value (raw): 0.744832, p-value (Bonferroni): 1.000000, p-value (FDR): 0.818024, variances are equal: False
# Comparison 31: Group Office vs Group Gift Cards, p-value (raw): 0.000349, p-value (Bonferroni): 0.066294, p-value (FDR): 0.000839, variances are equal: False
# Comparison 32: Group Office vs Group Housewares, p-value (raw): 0.421045, p-value (Bonferroni): 1.000000, p-value (FDR): 0.536903, variances are equal: False
# Comparison 33: Group Office vs Group Android, p-value (raw): 0.534567, p-value (Bonferroni): 1.000000, p-value (FDR): 0.634799, variances are equal: False
# Comparison 34: Group Office vs Group Bottles, p-value (raw): 0.609789, p-value (Bonferroni): 1.000000, p-value (FDR): 0.697951, variances are equal: False
# Comparison 35: Group Office vs Group Backpacks, p-value (raw): 0.191445, p-value (Bonferroni): 1.000000, p-value (FDR): 0.286177, variances are equal: False
# Comparison 36: Group Office vs Group Accessories, p-value (raw): 0.819538, p-value (Bonferroni): 1.000000, p-value (FDR): 0.855562, variances are equal: False
# Comparison 37: Group Office vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 38: Group Bags vs Group Drinkware, p-value (raw): 0.004020, p-value (Bonferroni): 0.763805, p-value (FDR): 0.008584, variances are equal: False
# Comparison 39: Group Bags vs Group Apparel, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 40: Group Bags vs Group Lifestyle, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 41: Group Bags vs Group Waze, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 42: Group Bags vs Group Fun, p-value (raw): 0.022469, p-value (Bonferroni): 1.000000, p-value (FDR): 0.045416, variances are equal: False
# Comparison 43: Group Bags vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 44: Group Bags vs Group Headgear, p-value (raw): 0.171499, p-value (Bonferroni): 1.000000, p-value (FDR): 0.262781, variances are equal: False
# Comparison 45: Group Bags vs Group Google, p-value (raw): 0.196551, p-value (Bonferroni): 1.000000, p-value (FDR): 0.287267, variances are equal: False
# Comparison 46: Group Bags vs Group Notebooks & Journals, p-value (raw): 0.007549, p-value (Bonferroni): 1.000000, p-value (FDR): 0.015936, variances are equal: False
# Comparison 47: Group Bags vs Group More Bags, p-value (raw): 0.153210, p-value (Bonferroni): 1.000000, p-value (FDR): 0.236665, variances are equal: False
# Comparison 48: Group Bags vs Group Gift Cards, p-value (raw): 0.001649, p-value (Bonferroni): 0.313354, p-value (FDR): 0.003687, variances are equal: False
# Comparison 49: Group Bags vs Group Housewares, p-value (raw): 0.000007, p-value (Bonferroni): 0.001259, p-value (FDR): 0.000019, variances are equal: False
# Comparison 50: Group Bags vs Group Android, p-value (raw): 0.112118, p-value (Bonferroni): 1.000000, p-value (FDR): 0.183136, variances are equal: False
# Comparison 51: Group Bags vs Group Bottles, p-value (raw): 0.000421, p-value (Bonferroni): 0.080067, p-value (FDR): 0.001001, variances are equal: False
# Comparison 52: Group Bags vs Group Backpacks, p-value (raw): 0.112773, p-value (Bonferroni): 1.000000, p-value (FDR): 0.183136, variances are equal: False
# Comparison 53: Group Bags vs Group Accessories, p-value (raw): 0.029829, p-value (Bonferroni): 1.000000, p-value (FDR): 0.058428, variances are equal: False
# Comparison 54: Group Bags vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 55: Group Drinkware vs Group Apparel, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 56: Group Drinkware vs Group Lifestyle, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 57: Group Drinkware vs Group Waze, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 58: Group Drinkware vs Group Fun, p-value (raw): 0.237055, p-value (Bonferroni): 1.000000, p-value (FDR): 0.338651, variances are equal: False
# Comparison 59: Group Drinkware vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 60: Group Drinkware vs Group Headgear, p-value (raw): 0.241781, p-value (Bonferroni): 1.000000, p-value (FDR): 0.342824, variances are equal: False
# Comparison 61: Group Drinkware vs Group Google, p-value (raw): 0.123592, p-value (Bonferroni): 1.000000, p-value (FDR): 0.195688, variances are equal: False
# Comparison 62: Group Drinkware vs Group Notebooks & Journals, p-value (raw): 0.000691, p-value (Bonferroni): 0.131381, p-value (FDR): 0.001622, variances are equal: False
# Comparison 63: Group Drinkware vs Group More Bags, p-value (raw): 0.465902, p-value (Bonferroni): 1.000000, p-value (FDR): 0.578571, variances are equal: False
# Comparison 64: Group Drinkware vs Group Gift Cards, p-value (raw): 0.000097, p-value (Bonferroni): 0.018440, p-value (FDR): 0.000246, variances are equal: False
# Comparison 65: Group Drinkware vs Group Housewares, p-value (raw): 0.143835, p-value (Bonferroni): 1.000000, p-value (FDR): 0.224005, variances are equal: False
# Comparison 66: Group Drinkware vs Group Android, p-value (raw): 0.307822, p-value (Bonferroni): 1.000000, p-value (FDR): 0.423813, variances are equal: False
# Comparison 67: Group Drinkware vs Group Bottles, p-value (raw): 0.190231, p-value (Bonferroni): 1.000000, p-value (FDR): 0.286177, variances are equal: False
# Comparison 68: Group Drinkware vs Group Backpacks, p-value (raw): 0.210730, p-value (Bonferroni): 1.000000, p-value (FDR): 0.303324, variances are equal: False
# Comparison 69: Group Drinkware vs Group Accessories, p-value (raw): 0.357957, p-value (Bonferroni): 1.000000, p-value (FDR): 0.478956, variances are equal: False
# Comparison 70: Group Drinkware vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 71: Group Apparel vs Group Lifestyle, p-value (raw): 0.417491, p-value (Bonferroni): 1.000000, p-value (FDR): 0.535968, variances are equal: False
# Comparison 72: Group Apparel vs Group Waze, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 73: Group Apparel vs Group Fun, p-value (raw): 0.589788, p-value (Bonferroni): 1.000000, p-value (FDR): 0.687483, variances are equal: False
# Comparison 74: Group Apparel vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 75: Group Apparel vs Group Headgear, p-value (raw): 0.103551, p-value (Bonferroni): 1.000000, p-value (FDR): 0.171084, variances are equal: False
# Comparison 76: Group Apparel vs Group Google, p-value (raw): 0.053672, p-value (Bonferroni): 1.000000, p-value (FDR): 0.099007, variances are equal: False
# Comparison 77: Group Apparel vs Group Notebooks & Journals, p-value (raw): 0.000005, p-value (Bonferroni): 0.001009, p-value (FDR): 0.000015, variances are equal: False
# Comparison 78: Group Apparel vs Group More Bags, p-value (raw): 0.770692, p-value (Bonferroni): 1.000000, p-value (FDR): 0.827297, variances are equal: False
# Comparison 79: Group Apparel vs Group Gift Cards, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 80: Group Apparel vs Group Housewares, p-value (raw): 0.794834, p-value (Bonferroni): 1.000000, p-value (FDR): 0.838991, variances are equal: False
# Comparison 81: Group Apparel vs Group Android, p-value (raw): 0.602640, p-value (Bonferroni): 1.000000, p-value (FDR): 0.693950, variances are equal: False
# Comparison 82: Group Apparel vs Group Bottles, p-value (raw): 0.331361, p-value (Bonferroni): 1.000000, p-value (FDR): 0.448158, variances are equal: False
# Comparison 83: Group Apparel vs Group Backpacks, p-value (raw): 0.000234, p-value (Bonferroni): 0.044491, p-value (FDR): 0.000570, variances are equal: False
# Comparison 84: Group Apparel vs Group Accessories, p-value (raw): 0.371633, p-value (Bonferroni): 1.000000, p-value (FDR): 0.493778, variances are equal: False
# Comparison 85: Group Apparel vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 86: Group Lifestyle vs Group Waze, p-value (raw): 0.000000, p-value (Bonferroni): 0.000002, p-value (FDR): 0.000000, variances are equal: False
# Comparison 87: Group Lifestyle vs Group Fun, p-value (raw): 0.562337, p-value (Bonferroni): 1.000000, p-value (FDR): 0.659531, variances are equal: False
# Comparison 88: Group Lifestyle vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 89: Group Lifestyle vs Group Headgear, p-value (raw): 0.096234, p-value (Bonferroni): 1.000000, p-value (FDR): 0.160389, variances are equal: False
# Comparison 90: Group Lifestyle vs Group Google, p-value (raw): 0.050083, p-value (Bonferroni): 1.000000, p-value (FDR): 0.094216, variances are equal: False
# Comparison 91: Group Lifestyle vs Group Notebooks & Journals, p-value (raw): 0.000004, p-value (Bonferroni): 0.000755, p-value (FDR): 0.000011, variances are equal: False
# Comparison 92: Group Lifestyle vs Group More Bags, p-value (raw): 0.741759, p-value (Bonferroni): 1.000000, p-value (FDR): 0.818024, variances are equal: False
# Comparison 93: Group Lifestyle vs Group Gift Cards, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 94: Group Lifestyle vs Group Housewares, p-value (raw): 0.939221, p-value (Bonferroni): 1.000000, p-value (FDR): 0.949213, variances are equal: False
# Comparison 95: Group Lifestyle vs Group Android, p-value (raw): 0.726501, p-value (Bonferroni): 1.000000, p-value (FDR): 0.807223, variances are equal: False
# Comparison 96: Group Lifestyle vs Group Bottles, p-value (raw): 0.332581, p-value (Bonferroni): 1.000000, p-value (FDR): 0.448158, variances are equal: False
# Comparison 97: Group Lifestyle vs Group Backpacks, p-value (raw): 0.002092, p-value (Bonferroni): 0.397447, p-value (FDR): 0.004621, variances are equal: False
# Comparison 98: Group Lifestyle vs Group Accessories, p-value (raw): 0.192793, p-value (Bonferroni): 1.000000, p-value (FDR): 0.286177, variances are equal: False
# Comparison 99: Group Lifestyle vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 100: Group Waze vs Group Fun, p-value (raw): 0.117770, p-value (Bonferroni): 1.000000, p-value (FDR): 0.189629, variances are equal: False
# Comparison 101: Group Waze vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 102: Group Waze vs Group Headgear, p-value (raw): 0.090966, p-value (Bonferroni): 1.000000, p-value (FDR): 0.155454, variances are equal: False
# Comparison 103: Group Waze vs Group Google, p-value (raw): 0.025922, p-value (Bonferroni): 1.000000, p-value (FDR): 0.051843, variances are equal: False
# Comparison 104: Group Waze vs Group Notebooks & Journals, p-value (raw): 0.000000, p-value (Bonferroni): 0.000011, p-value (FDR): 0.000000, variances are equal: False
# Comparison 105: Group Waze vs Group More Bags, p-value (raw): 0.001090, p-value (Bonferroni): 0.207130, p-value (FDR): 0.002466, variances are equal: False
# Comparison 106: Group Waze vs Group Gift Cards, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 107: Group Waze vs Group Housewares, p-value (raw): 0.041428, p-value (Bonferroni): 1.000000, p-value (FDR): 0.079508, variances are equal: False
# Comparison 108: Group Waze vs Group Android, p-value (raw): 0.195794, p-value (Bonferroni): 1.000000, p-value (FDR): 0.287267, variances are equal: False
# Comparison 109: Group Waze vs Group Bottles, p-value (raw): 0.000809, p-value (Bonferroni): 0.153651, p-value (FDR): 0.001851, variances are equal: False
# Comparison 110: Group Waze vs Group Backpacks, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 111: Group Waze vs Group Accessories, p-value (raw): 0.022446, p-value (Bonferroni): 1.000000, p-value (FDR): 0.045416, variances are equal: False
# Comparison 112: Group Waze vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 113: Group Fun vs Group Nest-Canada, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 114: Group Fun vs Group Headgear, p-value (raw): 0.492121, p-value (Bonferroni): 1.000000, p-value (FDR): 0.595561, variances are equal: False
# Comparison 115: Group Fun vs Group Google, p-value (raw): 0.073259, p-value (Bonferroni): 1.000000, p-value (FDR): 0.129829, variances are equal: False
# Comparison 116: Group Fun vs Group Notebooks & Journals, p-value (raw): 0.052134, p-value (Bonferroni): 1.000000, p-value (FDR): 0.097113, variances are equal: False
# Comparison 117: Group Fun vs Group More Bags, p-value (raw): 0.985395, p-value (Bonferroni): 1.000000, p-value (FDR): 0.985395, variances are equal: False
# Comparison 118: Group Fun vs Group Gift Cards, p-value (raw): 0.000097, p-value (Bonferroni): 0.018474, p-value (FDR): 0.000246, variances are equal: False
# Comparison 119: Group Fun vs Group Housewares, p-value (raw): 0.663565, p-value (Bonferroni): 1.000000, p-value (FDR): 0.750461, variances are equal: False
# Comparison 120: Group Fun vs Group Android, p-value (raw): 0.627964, p-value (Bonferroni): 1.000000, p-value (FDR): 0.714450, variances are equal: False
# Comparison 121: Group Fun vs Group Bottles, p-value (raw): 0.881282, p-value (Bonferroni): 1.000000, p-value (FDR): 0.895421, variances are equal: False
# Comparison 122: Group Fun vs Group Backpacks, p-value (raw): 0.041130, p-value (Bonferroni): 1.000000, p-value (FDR): 0.079508, variances are equal: False
# Comparison 123: Group Fun vs Group Accessories, p-value (raw): 0.749797, p-value (Bonferroni): 1.000000, p-value (FDR): 0.818744, variances are equal: False
# Comparison 124: Group Fun vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 125: Group Nest-Canada vs Group Headgear, p-value (raw): 0.328828, p-value (Bonferroni): 1.000000, p-value (FDR): 0.448158, variances are equal: False
# Comparison 126: Group Nest-Canada vs Group Google, p-value (raw): 0.121370, p-value (Bonferroni): 1.000000, p-value (FDR): 0.193784, variances are equal: False
# Comparison 127: Group Nest-Canada vs Group Notebooks & Journals, p-value (raw): 0.028229, p-value (Bonferroni): 1.000000, p-value (FDR): 0.055871, variances are equal: False
# Comparison 128: Group Nest-Canada vs Group More Bags, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 129: Group Nest-Canada vs Group Gift Cards, p-value (raw): 0.000000, p-value (Bonferroni): 0.000021, p-value (FDR): 0.000000, variances are equal: False
# Comparison 130: Group Nest-Canada vs Group Housewares, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 131: Group Nest-Canada vs Group Android, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 132: Group Nest-Canada vs Group Bottles, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 133: Group Nest-Canada vs Group Backpacks, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 134: Group Nest-Canada vs Group Accessories, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 135: Group Nest-Canada vs Group Nest, p-value (raw): 0.444400, p-value (Bonferroni): 1.000000, p-value (FDR): 0.559179, variances are equal: False
# Comparison 136: Group Headgear vs Group Google, p-value (raw): 0.856811, p-value (Bonferroni): 1.000000, p-value (FDR): 0.884751, variances are equal: False
# Comparison 137: Group Headgear vs Group Notebooks & Journals, p-value (raw): 0.869029, p-value (Bonferroni): 1.000000, p-value (FDR): 0.887718, variances are equal: False
# Comparison 138: Group Headgear vs Group More Bags, p-value (raw): 0.683862, p-value (Bonferroni): 1.000000, p-value (FDR): 0.768839, variances are equal: False
# Comparison 139: Group Headgear vs Group Gift Cards, p-value (raw): 0.980180, p-value (Bonferroni): 1.000000, p-value (FDR): 0.985366, variances are equal: False
# Comparison 140: Group Headgear vs Group Housewares, p-value (raw): 0.526623, p-value (Bonferroni): 1.000000, p-value (FDR): 0.629298, variances are equal: False
# Comparison 141: Group Headgear vs Group Android, p-value (raw): 0.714069, p-value (Bonferroni): 1.000000, p-value (FDR): 0.798078, variances are equal: False
# Comparison 142: Group Headgear vs Group Bottles, p-value (raw): 0.401819, p-value (Bonferroni): 1.000000, p-value (FDR): 0.519357, variances are equal: False
# Comparison 143: Group Headgear vs Group Backpacks, p-value (raw): 0.829607, p-value (Bonferroni): 1.000000, p-value (FDR): 0.861341, variances are equal: False
# Comparison 144: Group Headgear vs Group Accessories, p-value (raw): 0.443162, p-value (Bonferroni): 1.000000, p-value (FDR): 0.559179, variances are equal: False
# Comparison 145: Group Headgear vs Group Nest, p-value (raw): 0.004021, p-value (Bonferroni): 0.763973, p-value (FDR): 0.008584, variances are equal: False
# Comparison 146: Group Google vs Group Notebooks & Journals, p-value (raw): 0.764126, p-value (Bonferroni): 1.000000, p-value (FDR): 0.824909, variances are equal: False
# Comparison 147: Group Google vs Group More Bags, p-value (raw): 0.138317, p-value (Bonferroni): 1.000000, p-value (FDR): 0.217192, variances are equal: False
# Comparison 148: Group Google vs Group Gift Cards, p-value (raw): 0.474714, p-value (Bonferroni): 1.000000, p-value (FDR): 0.585686, variances are equal: False
# Comparison 149: Group Google vs Group Housewares, p-value (raw): 0.049333, p-value (Bonferroni): 1.000000, p-value (FDR): 0.093733, variances are equal: False
# Comparison 150: Group Google vs Group Android, p-value (raw): 0.203785, p-value (Bonferroni): 1.000000, p-value (FDR): 0.295567, variances are equal: False
# Comparison 151: Group Google vs Group Bottles, p-value (raw): 0.072908, p-value (Bonferroni): 1.000000, p-value (FDR): 0.129829, variances are equal: False
# Comparison 152: Group Google vs Group Backpacks, p-value (raw): 0.288808, p-value (Bonferroni): 1.000000, p-value (FDR): 0.403482, variances are equal: False
# Comparison 153: Group Google vs Group Accessories, p-value (raw): 0.089069, p-value (Bonferroni): 1.000000, p-value (FDR): 0.153846, variances are equal: False
# Comparison 154: Group Google vs Group Nest, p-value (raw): 0.014198, p-value (Bonferroni): 1.000000, p-value (FDR): 0.029322, variances are equal: False
# Comparison 155: Group Notebooks & Journals vs Group More Bags, p-value (raw): 0.244742, p-value (Bonferroni): 1.000000, p-value (FDR): 0.344452, variances are equal: False
# Comparison 156: Group Notebooks & Journals vs Group Gift Cards, p-value (raw): 0.784431, p-value (Bonferroni): 1.000000, p-value (FDR): 0.832637, variances are equal: False
# Comparison 157: Group Notebooks & Journals vs Group Housewares, p-value (raw): 0.073798, p-value (Bonferroni): 1.000000, p-value (FDR): 0.129829, variances are equal: False
# Comparison 158: Group Notebooks & Journals vs Group Android, p-value (raw): 0.303698, p-value (Bonferroni): 1.000000, p-value (FDR): 0.421188, variances are equal: False
# Comparison 159: Group Notebooks & Journals vs Group Bottles, p-value (raw): 0.000078, p-value (Bonferroni): 0.014779, p-value (FDR): 0.000202, variances are equal: False
# Comparison 160: Group Notebooks & Journals vs Group Backpacks, p-value (raw): 0.484861, p-value (Bonferroni): 1.000000, p-value (FDR): 0.591621, variances are equal: False
# Comparison 161: Group Notebooks & Journals vs Group Accessories, p-value (raw): 0.000740, p-value (Bonferroni): 0.140518, p-value (FDR): 0.001714, variances are equal: False
# Comparison 162: Group Notebooks & Journals vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000002, p-value (FDR): 0.000000, variances are equal: False
# Comparison 163: Group More Bags vs Group Gift Cards, p-value (raw): 0.000000, p-value (Bonferroni): 0.000009, p-value (FDR): 0.000000, variances are equal: False
# Comparison 164: Group More Bags vs Group Housewares, p-value (raw): 0.485752, p-value (Bonferroni): 1.000000, p-value (FDR): 0.591621, variances are equal: False
# Comparison 165: Group More Bags vs Group Android, p-value (raw): 0.067205, p-value (Bonferroni): 1.000000, p-value (FDR): 0.122778, variances are equal: False
# Comparison 166: Group More Bags vs Group Bottles, p-value (raw): 0.865738, p-value (Bonferroni): 1.000000, p-value (FDR): 0.887718, variances are equal: False
# Comparison 167: Group More Bags vs Group Backpacks, p-value (raw): 0.000008, p-value (Bonferroni): 0.001467, p-value (FDR): 0.000021, variances are equal: False
# Comparison 168: Group More Bags vs Group Accessories, p-value (raw): 0.800126, p-value (Bonferroni): 1.000000, p-value (FDR): 0.839911, variances are equal: False
# Comparison 169: Group More Bags vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 170: Group Gift Cards vs Group Housewares, p-value (raw): 0.000000, p-value (Bonferroni): 0.000002, p-value (FDR): 0.000000, variances are equal: False
# Comparison 171: Group Gift Cards vs Group Android, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 172: Group Gift Cards vs Group Bottles, p-value (raw): 0.000000, p-value (Bonferroni): 0.000044, p-value (FDR): 0.000001, variances are equal: False
# Comparison 173: Group Gift Cards vs Group Backpacks, p-value (raw): 0.014193, p-value (Bonferroni): 1.000000, p-value (FDR): 0.029322, variances are equal: False
# Comparison 174: Group Gift Cards vs Group Accessories, p-value (raw): 0.000167, p-value (Bonferroni): 0.031803, p-value (FDR): 0.000413, variances are equal: False
# Comparison 175: Group Gift Cards vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000009, p-value (FDR): 0.000000, variances are equal: False
# Comparison 176: Group Housewares vs Group Android, p-value (raw): 0.550396, p-value (Bonferroni): 1.000000, p-value (FDR): 0.649536, variances are equal: False
# Comparison 177: Group Housewares vs Group Bottles, p-value (raw): 0.389058, p-value (Bonferroni): 1.000000, p-value (FDR): 0.506308, variances are equal: False
# Comparison 178: Group Housewares vs Group Backpacks, p-value (raw): 0.000002, p-value (Bonferroni): 0.000303, p-value (FDR): 0.000005, variances are equal: False
# Comparison 179: Group Housewares vs Group Accessories, p-value (raw): 0.455432, p-value (Bonferroni): 1.000000, p-value (FDR): 0.569290, variances are equal: False
# Comparison 180: Group Housewares vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 181: Group Android vs Group Bottles, p-value (raw): 0.376601, p-value (Bonferroni): 1.000000, p-value (FDR): 0.496904, variances are equal: False
# Comparison 182: Group Android vs Group Backpacks, p-value (raw): 0.000001, p-value (Bonferroni): 0.000152, p-value (FDR): 0.000002, variances are equal: False
# Comparison 183: Group Android vs Group Accessories, p-value (raw): 0.523311, p-value (Bonferroni): 1.000000, p-value (FDR): 0.629298, variances are equal: False
# Comparison 184: Group Android vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 185: Group Bottles vs Group Backpacks, p-value (raw): 0.002292, p-value (Bonferroni): 0.435405, p-value (FDR): 0.005005, variances are equal: False
# Comparison 186: Group Bottles vs Group Accessories, p-value (raw): 0.779343, p-value (Bonferroni): 1.000000, p-value (FDR): 0.831883, variances are equal: False
# Comparison 187: Group Bottles vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 188: Group Backpacks vs Group Accessories, p-value (raw): 0.091636, p-value (Bonferroni): 1.000000, p-value (FDR): 0.155454, variances are equal: False
# Comparison 189: Group Backpacks vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 190: Group Accessories vs Group Nest, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# ==================================================
#
# Impact of coupon usage on sales within category: month
#
# month 2019-01: t-statistic = -0.6025, p-value = 0.5469, variances are equal: True
# month 2019-02: t-statistic = -1.0529, p-value = 0.2925, variances are equal: True
# month 2019-03: t-statistic = -0.7454, p-value = 0.4561, variances are equal: True
# month 2019-04: t-statistic = -0.1700, p-value = 0.8650, variances are equal: True
# month 2019-05: t-statistic = -0.4662, p-value = 0.6411, variances are equal: True
# month 2019-06: t-statistic = -1.5871, p-value = 0.1126, variances are equal: True
# month 2019-07: t-statistic = -1.1533, p-value = 0.2489, variances are equal: True
# month 2019-08: t-statistic = 0.0729, p-value = 0.9419, variances are equal: True
# month 2019-09: t-statistic = 0.8281, p-value = 0.4077, variances are equal: True
# month 2019-10: t-statistic = -0.1341, p-value = 0.8934, variances are equal: True
# month 2019-11: t-statistic = -0.2145, p-value = 0.8302, variances are equal: True
# month 2019-12: t-statistic = -1.2413, p-value = 0.2146, variances are equal: True
# Pairwise t-tests within category: month
#
# Comparison 1: Group 2019-01 vs Group 2019-02, p-value (raw): 0.308502, p-value (Bonferroni): 1.000000, p-value (FDR): 0.363592, variances are equal: False
# Comparison 2: Group 2019-01 vs Group 2019-03, p-value (raw): 0.000134, p-value (Bonferroni): 0.008860, p-value (FDR): 0.000295, variances are equal: False
# Comparison 3: Group 2019-01 vs Group 2019-04, p-value (raw): 0.700741, p-value (Bonferroni): 1.000000, p-value (FDR): 0.734110, variances are equal: False
# Comparison 4: Group 2019-01 vs Group 2019-05, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 5: Group 2019-01 vs Group 2019-06, p-value (raw): 0.000000, p-value (Bonferroni): 0.000005, p-value (FDR): 0.000000, variances are equal: False
# Comparison 6: Group 2019-01 vs Group 2019-07, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 7: Group 2019-01 vs Group 2019-08, p-value (raw): 0.000004, p-value (Bonferroni): 0.000260, p-value (FDR): 0.000010, variances are equal: False
# Comparison 8: Group 2019-01 vs Group 2019-09, p-value (raw): 0.031460, p-value (Bonferroni): 1.000000, p-value (FDR): 0.044178, variances are equal: False
# Comparison 9: Group 2019-01 vs Group 2019-10, p-value (raw): 0.618826, p-value (Bonferroni): 1.000000, p-value (FDR): 0.658750, variances are equal: False
# Comparison 10: Group 2019-01 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 11: Group 2019-01 vs Group 2019-12, p-value (raw): 0.009802, p-value (Bonferroni): 0.646964, p-value (FDR): 0.014704, variances are equal: False
# Comparison 12: Group 2019-02 vs Group 2019-03, p-value (raw): 0.020010, p-value (Bonferroni): 1.000000, p-value (FDR): 0.029348, variances are equal: False
# Comparison 13: Group 2019-02 vs Group 2019-04, p-value (raw): 0.884857, p-value (Bonferroni): 1.000000, p-value (FDR): 0.901122, variances are equal: False
# Comparison 14: Group 2019-02 vs Group 2019-05, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 15: Group 2019-02 vs Group 2019-06, p-value (raw): 0.000131, p-value (Bonferroni): 0.008631, p-value (FDR): 0.000295, variances are equal: False
# Comparison 16: Group 2019-02 vs Group 2019-07, p-value (raw): 0.000001, p-value (Bonferroni): 0.000054, p-value (FDR): 0.000002, variances are equal: False
# Comparison 17: Group 2019-02 vs Group 2019-08, p-value (raw): 0.002694, p-value (Bonferroni): 0.177828, p-value (FDR): 0.004560, variances are equal: False
# Comparison 18: Group 2019-02 vs Group 2019-09, p-value (raw): 0.325776, p-value (Bonferroni): 1.000000, p-value (FDR): 0.377215, variances are equal: False
# Comparison 19: Group 2019-02 vs Group 2019-10, p-value (raw): 0.602120, p-value (Bonferroni): 1.000000, p-value (FDR): 0.651474, variances are equal: False
# Comparison 20: Group 2019-02 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 21: Group 2019-02 vs Group 2019-12, p-value (raw): 0.001152, p-value (Bonferroni): 0.076035, p-value (FDR): 0.002236, variances are equal: False
# Comparison 22: Group 2019-03 vs Group 2019-04, p-value (raw): 0.152835, p-value (Bonferroni): 1.000000, p-value (FDR): 0.193982, variances are equal: False
# Comparison 23: Group 2019-03 vs Group 2019-05, p-value (raw): 0.000000, p-value (Bonferroni): 0.000005, p-value (FDR): 0.000000, variances are equal: False
# Comparison 24: Group 2019-03 vs Group 2019-06, p-value (raw): 0.062656, p-value (Bonferroni): 1.000000, p-value (FDR): 0.084393, variances are equal: False
# Comparison 25: Group 2019-03 vs Group 2019-07, p-value (raw): 0.001829, p-value (Bonferroni): 0.120699, p-value (FDR): 0.003449, variances are equal: False
# Comparison 26: Group 2019-03 vs Group 2019-08, p-value (raw): 0.042431, p-value (Bonferroni): 1.000000, p-value (FDR): 0.058343, variances are equal: False
# Comparison 27: Group 2019-03 vs Group 2019-09, p-value (raw): 0.186225, p-value (Bonferroni): 1.000000, p-value (FDR): 0.227609, variances are equal: False
# Comparison 28: Group 2019-03 vs Group 2019-10, p-value (raw): 0.001886, p-value (Bonferroni): 0.124463, p-value (FDR): 0.003457, variances are equal: False
# Comparison 29: Group 2019-03 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 30: Group 2019-03 vs Group 2019-12, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 31: Group 2019-04 vs Group 2019-05, p-value (raw): 0.000181, p-value (Bonferroni): 0.011961, p-value (FDR): 0.000386, variances are equal: False
# Comparison 32: Group 2019-04 vs Group 2019-06, p-value (raw): 0.020644, p-value (Bonferroni): 1.000000, p-value (FDR): 0.029620, variances are equal: False
# Comparison 33: Group 2019-04 vs Group 2019-07, p-value (raw): 0.002598, p-value (Bonferroni): 0.171439, p-value (FDR): 0.004512, variances are equal: False
# Comparison 34: Group 2019-04 vs Group 2019-08, p-value (raw): 0.006359, p-value (Bonferroni): 0.419663, p-value (FDR): 0.009760, variances are equal: False
# Comparison 35: Group 2019-04 vs Group 2019-09, p-value (raw): 0.458598, p-value (Bonferroni): 1.000000, p-value (FDR): 0.513008, variances are equal: False
# Comparison 36: Group 2019-04 vs Group 2019-10, p-value (raw): 0.894776, p-value (Bonferroni): 1.000000, p-value (FDR): 0.901122, variances are equal: False
# Comparison 37: Group 2019-04 vs Group 2019-11, p-value (raw): 0.000348, p-value (Bonferroni): 0.022953, p-value (FDR): 0.000717, variances are equal: False
# Comparison 38: Group 2019-04 vs Group 2019-12, p-value (raw): 0.078381, p-value (Bonferroni): 1.000000, p-value (FDR): 0.103463, variances are equal: False
# Comparison 39: Group 2019-05 vs Group 2019-06, p-value (raw): 0.003422, p-value (Bonferroni): 0.225852, p-value (FDR): 0.005509, variances are equal: False
# Comparison 40: Group 2019-05 vs Group 2019-07, p-value (raw): 0.253087, p-value (Bonferroni): 1.000000, p-value (FDR): 0.303704, variances are equal: False
# Comparison 41: Group 2019-05 vs Group 2019-08, p-value (raw): 0.585056, p-value (Bonferroni): 1.000000, p-value (FDR): 0.643562, variances are equal: False
# Comparison 42: Group 2019-05 vs Group 2019-09, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 43: Group 2019-05 vs Group 2019-10, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 44: Group 2019-05 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 45: Group 2019-05 vs Group 2019-12, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 46: Group 2019-06 vs Group 2019-07, p-value (raw): 0.182210, p-value (Bonferroni): 1.000000, p-value (FDR): 0.226903, variances are equal: False
# Comparison 47: Group 2019-06 vs Group 2019-08, p-value (raw): 0.342393, p-value (Bonferroni): 1.000000, p-value (FDR): 0.389619, variances are equal: False
# Comparison 48: Group 2019-06 vs Group 2019-09, p-value (raw): 0.003243, p-value (Bonferroni): 0.214054, p-value (FDR): 0.005351, variances are equal: False
# Comparison 49: Group 2019-06 vs Group 2019-10, p-value (raw): 0.000003, p-value (Bonferroni): 0.000209, p-value (FDR): 0.000009, variances are equal: False
# Comparison 50: Group 2019-06 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 51: Group 2019-06 vs Group 2019-12, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 52: Group 2019-07 vs Group 2019-08, p-value (raw): 0.901122, p-value (Bonferroni): 1.000000, p-value (FDR): 0.901122, variances are equal: False
# Comparison 53: Group 2019-07 vs Group 2019-09, p-value (raw): 0.000036, p-value (Bonferroni): 0.002359, p-value (FDR): 0.000084, variances are equal: False
# Comparison 54: Group 2019-07 vs Group 2019-10, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 55: Group 2019-07 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 56: Group 2019-07 vs Group 2019-12, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 57: Group 2019-08 vs Group 2019-09, p-value (raw): 0.002218, p-value (Bonferroni): 0.146372, p-value (FDR): 0.003956, variances are equal: False
# Comparison 58: Group 2019-08 vs Group 2019-10, p-value (raw): 0.000027, p-value (Bonferroni): 0.001781, p-value (FDR): 0.000066, variances are equal: False
# Comparison 59: Group 2019-08 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 60: Group 2019-08 vs Group 2019-12, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 61: Group 2019-09 vs Group 2019-10, p-value (raw): 0.109204, p-value (Bonferroni): 1.000000, p-value (FDR): 0.141323, variances are equal: False
# Comparison 62: Group 2019-09 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 63: Group 2019-09 vs Group 2019-12, p-value (raw): 0.000011, p-value (Bonferroni): 0.000715, p-value (FDR): 0.000027, variances are equal: False
# Comparison 64: Group 2019-10 vs Group 2019-11, p-value (raw): 0.000000, p-value (Bonferroni): 0.000000, p-value (FDR): 0.000000, variances are equal: False
# Comparison 65: Group 2019-10 vs Group 2019-12, p-value (raw): 0.003544, p-value (Bonferroni): 0.233887, p-value (FDR): 0.005569, variances are equal: False
# Comparison 66: Group 2019-11 vs Group 2019-12, p-value (raw): 0.001066, p-value (Bonferroni): 0.070326, p-value (FDR): 0.002131, variances are equal: False
# ==================================================
#
# Impact of coupon usage on sales within category: gender
#
# gender M: t-statistic = -0.4940, p-value = 0.6213, variances are equal: True
# gender F: t-statistic = -1.3725, p-value = 0.1699, variances are equal: True
#
# Pairwise t-tests within category: gender
#
# Comparison 1: Group M vs Group F, p-value (raw): 0.166230, p-value (Bonferroni): 0.166230, p-value (FDR): 0.166230, variances are equal: True
# ==================================================
#
# Impact of coupon usage on sales within category: location
#
# location Chicago: t-statistic = 0.2837, p-value = 0.7767, variances are equal: True
# location California: t-statistic = -1.9610, p-value = 0.0500, variances are equal: True
# location New York: t-statistic = -0.1119, p-value = 0.9109, variances are equal: True
# location Washington DC: t-statistic = -1.3793, p-value = 0.1680, variances are equal: True
# location New Jersey: t-statistic = 0.0295, p-value = 0.9764, variances are equal: True
#
# Pairwise t-tests within category: location
#
# Comparison 1: Group Chicago vs Group California, p-value (raw): 0.437970, p-value (Bonferroni): 1.000000, p-value (FDR): 0.580516, variances are equal: True
# Comparison 2: Group Chicago vs Group New York, p-value (raw): 0.070003, p-value (Bonferroni): 0.700030, p-value (FDR): 0.342203, variances are equal: True
# Comparison 3: Group Chicago vs Group Washington DC, p-value (raw): 0.897972, p-value (Bonferroni): 1.000000, p-value (FDR): 0.897972, variances are equal: True
# Comparison 4: Group Chicago vs Group New Jersey, p-value (raw): 0.464413, p-value (Bonferroni): 1.000000, p-value (FDR): 0.580516, variances are equal: True
# Comparison 5: Group California vs Group New York, p-value (raw): 0.161939, p-value (Bonferroni): 1.000000, p-value (FDR): 0.342203, variances are equal: True
# Comparison 6: Group California vs Group Washington DC, p-value (raw): 0.735274, p-value (Bonferroni): 1.000000, p-value (FDR): 0.816971, variances are equal: True
# Comparison 7: Group California vs Group New Jersey, p-value (raw): 0.127131, p-value (Bonferroni): 1.000000, p-value (FDR): 0.342203, variances are equal: True
# Comparison 8: Group New York vs Group Washington DC, p-value (raw): 0.171101, p-value (Bonferroni): 1.000000, p-value (FDR): 0.342203, variances are equal: True
# Comparison 9: Group New York vs Group New Jersey, p-value (raw): 0.026571, p-value (Bonferroni): 0.265709, p-value (FDR): 0.265709, variances are equal: True
# Comparison 10: Group Washington DC vs Group New Jersey, p-value (raw): 0.429150, p-value (Bonferroni): 1.000000, p-value (FDR): 0.580516, variances are equal: True
# ==================================================
#
# Impact of coupon usage on sales within category: discount_pct
#
# discount_pct 10.0: t-statistic = -0.8174, p-value = 0.4137, variances are equal: True
# discount_pct nan: t-statistic = -0.1971, p-value = 0.8440, variances are equal: True
# discount_pct 20.0: t-statistic = -0.2735, p-value = 0.7844, variances are equal: True
# discount_pct 30.0: t-statistic = -1.4995, p-value = 0.1338, variances are equal: True
# Pairwise t-tests within category: discount_pct
#
# Comparison 1: Group 10.0 vs Group nan, p-value (raw): 0.467391, p-value (Bonferroni): 1.000000, p-value (FDR): 0.701086, variances are equal: True
# Comparison 2: Group 10.0 vs Group 20.0, p-value (raw): 0.357032, p-value (Bonferroni): 1.000000, p-value (FDR): 0.701086, variances are equal: True
# Comparison 3: Group 10.0 vs Group 30.0, p-value (raw): 0.757476, p-value (Bonferroni): 1.000000, p-value (FDR): 0.757476, variances are equal: True
# Comparison 4: Group nan vs Group 20.0, p-value (raw): 0.592993, p-value (Bonferroni): 1.000000, p-value (FDR): 0.711592, variances are equal: True
# Comparison 5: Group nan vs Group 30.0, p-value (raw): 0.244262, p-value (Bonferroni): 1.000000, p-value (FDR): 0.701086, variances are equal: True
# Comparison 6: Group 20.0 vs Group 30.0, p-value (raw): 0.165958, p-value (Bonferroni): 0.995750, p-value (FDR): 0.701086, variances are equal: True
# ==================================================
